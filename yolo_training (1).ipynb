# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-63c068de-44c0-4b47-83da-a47047c01b32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-63c068de-44c0-4b47-83da-a47047c01b32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

with zipfile.ZipFile("dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/dataset")  # Extract to a folder in /content
print("Files extracted to /content/dataset")
# Out:
# Files extracted to /content/dataset

# %%
with open("/content/Data.yaml", "r") as file:
    print(file.read())
# Out:
# train: /content/dataset/output_folder/train
# val: /content/dataset/output_folder/test
# nc: 5
# names: ["keyboard","mouse","laptop","monitor","mobile"]

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 285MB/s]

# %%
model.train(data="Data.yaml", epochs=80, batch=8)
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
plt.imshow(plt.imread('/content/runs/detect/train/results.png'))

# %%
model1 = YOLO('runs/detect/train/weights/best.pt')  # Path to the best weights file
model.val(data='Data.yaml')
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/dataset/output_folder/test/labels.cache... 19 images, 58 backgrounds, 6 corrupt: 100%|██████████| 77/77 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/dataset/output_folder/test/images/20210101_12_01_28_000_PRE8DAtpJ1Q5yPNHZdoqaOWxHNA2_F_3264_2448.jpg.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.2809]
# val: WARNING ⚠️ /content/dataset/output_folder/test/images/20210102_19_07_28_000_kZtbG1otWiPSOj3R1bPYdq2J3Bz1_F_4160_3120.jpg.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.6494]
# val: WARNING ⚠️ /content/dataset/output_folder/test/images/20210103_13_56_01_000_ED8APwkrunTluVxK3VsSuEPMXAr2_T_3120_4160.jpg.jpg: ignoring corrupt image/label: negative label values [   -0.16581]
# ...
